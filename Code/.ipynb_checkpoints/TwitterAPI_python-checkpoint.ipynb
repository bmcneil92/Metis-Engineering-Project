# %%
import creds
from ratelimit import limits, sleep_and_retry
import requests
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import *
from sqlalchemy.orm import sessionmaker
import datetime
from datetime import timedelta
import re

#### set key parameters
yesterday_date = (datetime.datetime.today().date() -timedelta(days=1)).strftime("%Y-%m-%d")
today_date = datetime.datetime.today().date().strftime("%Y-%m-%d")
FIFTEEN_MINUTES = 920

engine = create_engine("sqlite:///crypto_db.db")
query = '''select coin_id from crypto_coins '''
df = pd.read_sql(query, engine)

header = {"Authorization": f"Bearer {creds.bearer_token}"}

# %%
## latest URL update below before running
#https://api.twitter.com/2/tweets/search/recent?start_time=2021-04-20T00:00:00Z&end_time=2021-04-21T00:00:00Z&tweet.fields=public_metrics,created_at&expansions=&user.fields=id,name,username&query=%23oxt -is:retweet lang:en -"earn free"

def create_header():
    auth_header = {"Authorization": f"Bearer {creds.bearer_token}"}
    return auth_header
    
def coin_list():
    engine = create_engine("sqlite:///crypto_db.db")
    query = '''select coin_id from crypto_coins '''
    df = pd.read_sql(query, engine)
    return df    


def twitter_api_url_get(coin_name, yesterday_date, today_date, next_page_token=None):
    
    start_date = f"start_time={yesterday_date}T00:00:00Z"
    end_date = f"end_time={today_date}T00:00:00Z"
    query = f"%23{coin_name} lang:en -is:retweet -\"earn free\""
    tweet_fields = "tweet.fields=public_metrics,created_at"
    user_fields = "user.fields=id,name,username"
    max_results = "max_results=10"
    
    if next_page_token == None:
        url = "https://api.twitter.com/2/tweets/search/recent?{}&{}&max_results=100&{}&expansions=&{}&query={}".format(
            start_date, end_date, tweet_fields, user_fields, query
        )
    else:
        url = "https://api.twitter.com/2/tweets/search/recent?{}&{}&max_results=100&{}&expansions=&{}&query={}&next_token={}".format(
            start_date, end_date, tweet_fields, user_fields, query, next_page_token
        )
    return url




@sleep_and_retry
@limits(calls=450, period=FIFTEEN_MINUTES)
def check_limit():
    '''Empty function used to check the call limit and wait the given time if it exceeds it.'''
    return



def get_something_from_api(header, url):
    check_limit()
    response = requests.get(url, headers=header)
    print(f'Twitter API Pull Results: {response.status_code}')
    response_json = response.json()
    return response_json




def next_page_token(json_text, coin_id, yesterday_date):
    try:
        next_page_token_code = json_text['meta']['next_token']
        print(f"Next Page {coin_id} for {yesterday_date}, moving on to next page - {next_page_token_code}.")
        return json_text['meta']['next_token']
    except KeyError:
        print(f"No more pages, {coin_id} completed for {yesterday_date}.")
        return None
              

def tweets_to_db(coin_id, tweet_json):

    heads = ['twitter_user_id', 'tweet_text', 'date_tweet_created','retweet_count', 
             'reply_count', 'like_count', 'quote_rt_count', 'coin_id', 'date_uploaded']
    
    engine = create_engine("sqlite:///crypto_db.db")
    
    upload_date = datetime.datetime.today().date()
    tweetdata = []
    for obj in tweet_json['data']:
        twitter_user_ids = obj['id']
        text_tweeted = obj['text']
        post_date = re.sub('[A-Z]', " ", obj['created_at']).strip()[:-4]
        retweet_count = obj['public_metrics']['retweet_count']
        reply_count = obj['public_metrics']['reply_count']
        like_count = obj['public_metrics']['like_count']
        quote_rt_count = obj['public_metrics']['quote_count']

        tweetobj_list = dict(zip(heads, [twitter_user_ids,
                                text_tweeted, 
                                post_date,
                                retweet_count,
                                reply_count,
                                like_count,
                                quote_rt_count,
                                coin_id,
                                upload_date]))

        tweetdata.append(tweetobj_list)



    df_tweet_data_output = pd.DataFrame(tweetdata)

    sqlite_connection = engine.connect()
    sqlite_table = "crypto_tweet_data"
    
    try:
        df_tweet_data_output.to_sql(sqlite_table, sqlite_connection, if_exists='append', index=False)
        return print(f"API call for {coin_id} successfully added to SQlLite DB.")
    except:
        return print(f"API call for {coin_id} was not successfully added to SQlLite DB.")  
    

    
def coinbase_api_pull(coin_id):
    price = requests.get(f'https://api.coinbase.com/v2/prices/{coin_id}-USD/spot').json()
    return (coin_id, price['data']['amount'], datetime.datetime.today().date())

# %%
for index, row in df.iterrows():
        current_coin = row['coin_id']
        api_url_creation = twitter_api_url_get(row['coin_id'], yesterday_date, today_date)
        api_callie = get_something_from_api(header, api_url_creation)
        tweets_to_db(current_coin, api_callie)
        next_token = next_page_token(api_callie, current_coin, yesterday_date)
        while next_token != None:
            next_page_url = twitter_api_url_get(row['coin_id'], yesterday_date, today_date, next_token)
            next_page_api_call = get_something_from_api(header, next_page_url)
            tweets_to_db(current_coin, next_page_api_call)
            next_token = next_page_token(next_page_api_call, current_coin, yesterday_date)
# Out:
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjg5d0s32cmtd825exzgnpda5.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfunmnlem2swe0q5zigcu9a5.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfjzpng377nvr1e61yq9g67x.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjf9ac5vpev6aa9ryc50po519.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjeykxtk44vbgk6f6ihd04oe5.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcxjgvedby5x9c578202qfst.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcx7b91116uxb8xa0pnm2wzh.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcmhxc2ifp7sn3g2bej0664d.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcbu16tsskrmyxpff52xl8ql.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhc11nqfnoe5oy7lygjltehrx.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhbq1me4ihwnrk4u6rcglimbh.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhb4ocyvlq3hw1r4i9ksovud9.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhatsvpge7e92e5ardonaafzx.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqha8e4q9fn2v6ps0pskmdgebh.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf8751tdkw8rkt2u5etfewzul.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7lopvd9kb6n7wr2e7ed2zy5.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7aooy9qylgaik0zu3b6gghp.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf6p3v23hee04zf4se13vbkal.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf63kjs4hjvwgeupq2nc5pw1p.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf5i2ocz8b2xmbdi72th6zgcd.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd36aavg4dzwtxct8a6h6ht31.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd2kkvtssqj8imsevnic4qvlp.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd1oi8x2rfrj3s124obczm8al.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd12vvjfo2e6dcii9ay8nwbct.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# Next Page ADA for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqayr0fyh45zis3wz5d34nav7h.
# Twitter API Pull Results: 200
# API call for ADA successfully added to SQlLite DB.
# No more pages, ADA completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for OXT successfully added to SQlLite DB.
# No more pages, OXT completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjggbinenwd0p6vjh7bbiln5p.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjgg8gjqjx699dff90i1fqp31.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjgg5envbtgx76z08dka29vul.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjg5nmpp2bw9szm6tw2uypy7x.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjg5j39pb47krk4mltrv4nq7x.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjg5g0r140bpaqq1tdsg76f7h.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjg5czahuheddob34858zhx19.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfutpcv42ffe30sdapa89fgd.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfuqmme2wj2pjoratk0p8fb1.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfukkzgt9p6cs885z53xrddp.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfk49qc0v8dib2lzais4sakd.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfjzrcv7pagxnf7bant3p18d.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfjv7ht7a4x27qdd3qh41zel.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjf9deon4qadsepu5q9xy6gzh.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjf9busevbublr6vmbcv8xg8t.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjf97bk1g8mk5gfe0gwvi01od.
# Twitter API Pull Results: 200
# API call for DOGE successfully added to SQlLite DB.
# Next Page DOGE for 2021-04-28, moving on to next page - b26v89c19zqg8o3fostt
 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhaiyyryedbmk6cm8bel1g6f1.
# Twitter API Pull Results: 200
# API call for XLM successfully added to SQlLite DB.
# Next Page XLM for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf6pbfbgmrwtotitxcmqi40vx.
# Twitter API Pull Results: 200
# API call for XLM successfully added to SQlLite DB.
# Next Page XLM for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd2ku0f5c0hubf2sq4jswb62l.
# Twitter API Pull Results: 200
# API call for XLM successfully added to SQlLite DB.
# Next Page XLM for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd12st86a8pquhu5ol3mf4kn1.
# Twitter API Pull Results: 200
# API call for XLM successfully added to SQlLite DB.
# No more pages, XLM completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for FIL successfully added to SQlLite DB.
# No more pages, FIL completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfum3ln1062yshg01vs9ka65.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjeyge5toc6a86vqpygos80vx.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcmr12g9vemohdatw38pa35p.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcbkyy6n7bp9se1bebz91bi5.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhbq97i5lxu7j8hifywrb3hbx.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhbf7ols346i858vk42be4jgd.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhatrdxy5m0osq2h1az0b7vct.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqha8e3nqi1valdwp49sc4i9vh.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7wip55hma7s6tuq0rfirhx9.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7lopfrkebqkuvrnmf08hwu5.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf708g9pav014sd579beehkl9.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf6p9y6sejo69x615qs1v2jy5.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf63s2z56sv735y6gcyegjqm5.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf5sv3qevpwg0x8xwetbwf1bx.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf5hwmxso0o0jj6h82gj4wby5.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd36gcib6vracd2h4y9bz8iv1.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd2vhvhx9j740i9miutrexf25.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd2kpfowzowlmnywsw8bd22d9.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# Next Page TRX for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd1dla3l7cig8wn0pvfc0m8al.
# Twitter API Pull Results: 200
# API call for TRX successfully added to SQlLite DB.
# No more pages, TRX completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for XMR successfully added to SQlLite DB.
# Next Page XMR for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7lk72dzfqz24ah8agu46yrh.
# Twitter API Pull Results: 200
# API call for XMR successfully added to SQlLite DB.
# No more pages, XMR completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for MIOTA successfully added to SQlLite DB.
# No more pages, MIOTA completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjey8t1skftdzbft5x8hmox31.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcbr0d8uvzixgdgqnrt96dfh.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhbq034mzlm4e371mj28yjerh.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhatobuedhcj22fclzte2k8l9.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7wfmek4r9skbc5xcseio4u5.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf6p8exd2hifl5zrwhjo3zud9.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd36aavjdi8k1kq7ahr4h47st.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd1ywzmge5wp8ls8xq1o8y1dp.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# Next Page MATIC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd0s1xrf51k2z0mldkear9rwd.
# Twitter API Pull Results: 200
# API call for MATIC successfully added to SQlLite DB.
# No more pages, MATIC completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for ZRX successfully added to SQlLite DB.
# No more pages, ZRX completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for GRT successfully added to SQlLite DB.
# Next Page GRT for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd1ywzmfc19qfm4ywxthtuxrx.
# Twitter API Pull Results: 200
# API call for GRT successfully added to SQlLite DB.
# No more pages, GRT completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjfum2yqueil3ar6vd3mozwql.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqjf95sxmms8dk3roytzkdysu5.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcxddj59842f0ytyp8lk0lfh.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhcbphbi1hccqi60wsc0jdcal.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhbq96v78yghrw6ouq1qi6kcd.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhbfaqa34f20um25r5n1t7y4d.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhatyymfog1udhwwrzxkox0fx.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqhaiyyrzgcgyxebf9evqqdpx9.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf879kegs5t4gobijdbqjq7wd.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7lop8alsndd0ih8aw014ayl.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf6zzatqzqhflx3bnp09m7jp9.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf5t16njkp3h4jxtij2remt19.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd36bucixactzzsd3gosy3c71.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd29x0jbafhgmqpnum2ii9gu5.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd1dmr0lzhuorge8rgf5milj1.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# Next Page LTC for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd0rssyhbrlejbsihzm5u48l9.
# Twitter API Pull Results: 200
# API call for LTC successfully added to SQlLite DB.
# No more pages, LTC completed for 2021-04-28.
# Twitter API Pull Results: 200
# API call for ALGO successfully added to SQlLite DB.
# Next Page ALGO for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqf7llou3rxu7vgbox3nsam6pp.
# Twitter API Pull Results: 200
# API call for ALGO successfully added to SQlLite DB.
# Next Page ALGO for 2021-04-28, moving on to next page - b26v89c19zqg8o3fosttqd2kmfavlbttr17b2nxgw01h9.
# Twitter API Pull Results: 200
# API call for ALGO successfully added to SQlLite DB.
# No more pages, ALGO completed for 2021-04-28.

# %%
def get_tweets():
    df_coins = coin_list()
    for index, row in df_coins.iterrows():
            current_coin = row['coin_id']
            api_url_creation = twitter_api_url_get(row['coin_id'], yesterday_date, today_date)
            api_callie = get_something_from_api(header, api_url_creation)
            tweets_to_db(current_coin, api_callie)
            next_token = next_page_token(api_callie, current_coin, '2021-04-25')
            while next_token != None:
                next_page_url = twitter_api_url_get(row['coin_id'], yesterday_date, today_date, next_token)
                next_page_api_call = get_something_from_api(header, next_page_url)
                tweets_to_db(current_coin, next_page_api_call)
                next_token = next_page_token(next_page_api_call, current_coin, yesterday_date)
